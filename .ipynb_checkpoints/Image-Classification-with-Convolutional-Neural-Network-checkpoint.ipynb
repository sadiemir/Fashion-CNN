# %% [markdown]
# Step 1: Import necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Step 2: load and explore the dataset

# %%
#load the dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

#print the shape of the data
print(f'x_train shape: {x_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'x_test shape: {x_test.shape}')
print(f'y_test shape: {y_test.shape}')

#visualize some sample images with their labels
fig, axes = plt.subplots(1,5, figsize = (10,2))
for i in range(5):
    axes[i].imshow(x_train[i], cmap='gray')
    axes[i].set_title(f'Label: {y_train[i]}')
    axes[i].axis('off')
plt.show()
# Out:
# x_train shape: (60000, 28, 28)
# y_train shape: (60000,)
# x_test shape: (10000, 28, 28)
# y_test shape: (10000,)

# %%
#Display a Sample Image with Pixel Values
# Choose an image index to display
image_index = 0

# Display the image
plt.figure(figsize=(5, 5))
plt.imshow(x_train[image_index].reshape(28, 28), cmap='gray')

# Overlay the pixel values
for i in range(28):
    for j in range(28):
        plt.text(j, i, f'{x_train[image_index][i, j]:.2f}', 
                 ha='center', va='center', color='red', fontsize=8)

plt.title(f'Label: {y_train[image_index].argmax()}')
plt.axis('off')
plt.show()

# %% [markdown]
# Step 3: Preprocess the data - by normalizing the pixel values and one-hot encoding the labels

# %%
#normalize the pixel values to the range [0,1], because neural network performs better when input data is scaled 

#to smaller and more uniform ranges. REMEMBER, normalizing or scaling helps the model to converge faster!
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

#Reshape the data to include the channel dimension (for grayscale images, it's 1) - from (60000,28,28) to (60000,28,28,1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

#one-hot encode the labels
#In this case, to_categorical(y_train, 10) converts the labels in y_train to a matrix where each label is represented by a one-hot vector.
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

#print the new shape of the data
print(f'x_train shape after preprocessing: {x_train.shape}')
print(f'y_train shape after preprocessing: {y_train.shape}')
# Out:
# x_train shape after preprocessing: (60000, 28, 28, 1)
# y_train shape after preprocessing: (60000, 10)

# %% [markdown]
# Step 4: Build the CNN model - using Sequential from Keras.

# %%
#This model will have several convolutional and pooling layers followed by fully connected layers:

#Initialize the mode
model = Sequential()

#add the first convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))

#add a pooling layer
model.add(MaxPooling2D((2, 2)))

#add the second convolutional layer
model.add(Conv2D(64, (3, 3), activation='relu'))

#add another pooling layer
model.add(MaxPooling2D((2,2)))

#Flatten the output from the convolutional layers
model.add(Flatten())

#add a fully connected layer 
model.add(Dense(128, activation='relu'))

#add the output layer
model.add(Dense(10, activation='softmax'))

#print the model summary
model.summary
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# <bound method Model.summary of <Sequential name=sequential, built=True>>

# %% [markdown]
# Step 5: Compile the model before training - determine the optimizer, loss function, evaluation metric

# %%
#compile the model
model.compile(optimizer= 'adam',
             loss= 'categorical_crossentropy',
             metrics= ['accuracy'])

# %% [markdown]
# Step 6: Train the model

# %%
# start with t small number of epochs to see how it performs
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.7746 - loss: 0.6195 - val_accuracy: 0.8707 - val_loss: 0.3557
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8861 - loss: 0.3107 - val_accuracy: 0.8912 - val_loss: 0.3031
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9035 - loss: 0.2630 - val_accuracy: 0.9009 - val_loss: 0.2753
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9159 - loss: 0.2238 - val_accuracy: 0.9063 - val_loss: 0.2581
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9259 - loss: 0.1987 - val_accuracy: 0.9052 - val_loss: 0.2627
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9367 - loss: 0.1690 - val_accuracy: 0.9143 - val_loss: 0.2493
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9436 - loss: 0.1509 - val_accuracy: 0.9161 - val_loss: 0.2509
# Epoch 8/10
# ...

# %% [markdown]
# Step 7: Evaluate the model on the test data

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9104 - loss: 0.3078
# Test accuracy: 0.9097999930381775

# %% [markdown]
# Step 8: Visualize the training process

# %%
#plot training and validation accuracy values

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')

#plot training and validation loss values
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()

# %% [markdown]
# We can work on this model to improve its performance, but first, let's save it:

# %%
#save the model using the recommended keras format
model.save('fashion_mnist_cnn.keras')

# %% [markdown]
# Now is time to load the model and start improving it:

# %%
from tensorflow.keras.models import load_model
#load the model
model = load_model('fashion_mnist_cnn.keras')

#recompile the model with the same optimizer ("adam")
model.compile(optimizer= 'adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = np.argmax(model.predict(x_test), axis=1)
y_true = np.argmax(y_test, axis=1)
cm = confusion_matrix(y_true, y_pred)

sns.heatmap(cm, annot=True, fmt="d")
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

print(classification_report(y_true, y_pred))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      1000
#            1       1.00      0.97      0.99      1000
#            2       0.85      0.87      0.86      1000
#            3       0.93      0.89      0.91      1000
#            4       0.89      0.85      0.87      1000
#            5       0.98      0.99      0.99      1000
#            6       0.70      0.80      0.75      1000
#            7       0.96      0.95      0.96      1000
#            8       0.99      0.97      0.98      1000
#            9       0.96      0.97      0.96      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000

# %% [markdown]
# - The heatmap shows the counts of TP, TN, FP, and FN.
# - The classification_report gives precision, recall, and F1-score for each class, as well as overall accuracy.

# %% [markdown]
# ### Time for fine tuning the model:
# Options are:
# - Adjust Hyperparameters: Tweak the learning rate, batch size, and number of epochs.
# - Modify Model Architecture: Experiment with adding/removing layers, changing activation functions, and applying regularization.
# - Data Augmentation: Use techniques like rotation, shifting, and flipping to generate more diverse training data.
# - Transfer Learning: Utilize pre-trained models and fine-tune them on your dataset.
# - Hyperparameter Tuning: Systematically search for the best combination of hyperparameters.

# %% [markdown]
# Option one: Adjust Hyperparameters: Tweak the learning rate, batch size, and number of epochs.

# %%
#learning Rate
#If your model is converging too slowly or getting stuck, try increasing the learning rate.
#If your model is oscillating or diverging, try decreasing the learning rate.

from tensorflow.keras.optimizers import Adam

#adjust learning rate
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#batch size
#Smaller batch sizes can lead to more stable training but might slow down the process.
#Larger batch sizes might speed up training but can result in less generalization.

model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9780 - loss: 0.0650 - val_accuracy: 0.9214 - val_loss: 0.2752
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9838 - loss: 0.0491 - val_accuracy: 0.9215 - val_loss: 0.2826
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9850 - loss: 0.0459 - val_accuracy: 0.9220 - val_loss: 0.2851
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9863 - loss: 0.0419 - val_accuracy: 0.9205 - val_loss: 0.2959
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9871 - loss: 0.0406 - val_accuracy: 0.9223 - val_loss: 0.3023
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9876 - loss: 0.0383 - val_accuracy: 0.9217 - val_loss: 0.3066
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9901 - loss: 0.0336 - val_accuracy: 0.9220 - val_loss: 0.3141
# Epoch 8/10
# ...

# %%
#let's check the accuracy of the model after all these changes on the test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9203 - loss: 0.3438
# Test accuracy: 0.9221000075340271

# %% [markdown]
# Option two: Modify Model Architecture: Experiment with adding/removing layers, changing activation functions, and applying regularization.
